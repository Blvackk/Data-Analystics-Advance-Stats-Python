# %%
import pandas as pd

# %%
df = pd.read_excel(r'E:\Naresh IT Notes\1 April - Pandas\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] =6,2

import warnings
warnings.filterwarnings('ignore')  #os error

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1 = sns.displot(df["InternetUsers"])

# %%
vis1 = sns.displot(df["InternetUsers"], bins =15)

# %%
# BOX PLOTS:
vis4 = sns.boxplot(data =df , x="IncomeGroup",y="BirthRate")   #BI-VARIATE ANALYSIS

# %%
vis5 = sns.lmplot(data =df , x="InternetUsers",y="BirthRate")   #Linear Model plot

# %%
vis6= sns.lmplot(data =df , x="InternetUsers",y="BirthRate", fit_reg = False)   #Linear Model plot

# %%
vis6= sns.lmplot(data =df , x="InternetUsers",y="BirthRate", fit_reg = False, hue ='IncomeGroup')   #Linear Model plot
