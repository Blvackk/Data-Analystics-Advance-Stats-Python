# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\prati\Downloads\archive\movie.csv')

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.shape
# Out:
# (27278, 3)

# %%
tags= pd.read_csv(r'C:\Users\prati\Downloads\archive\tag.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
ratings= pd.read_csv(r'C:\Users\prati\Downloads\archive\rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.iloc[0]   #iloc --> integer locqtion
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %%
tags.iloc[2]
# Out:
# userId                        65
# movieId                      353
# tag                    dark hero
# timestamp    2013-05-10 01:41:19
# Name: 2, dtype: object

# %%
row_0 = tags.iloc[2]
row_0
# Out:
# userId                        65
# movieId                      353
# tag                    dark hero
# timestamp    2013-05-10 01:41:19
# Name: 2, dtype: object

# %%
row_0.index  #index fn --> prints the index of the following rows
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
print(row_0['userId'])
# Out:
# 65
